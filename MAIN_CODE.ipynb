# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import tkinter

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random


# begin to train the chatbot

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('/Users/joaquindelaguardia/Desktop/intents.json').read()
intents = json.loads(data_file)


# load jason file into intents


for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

#building the model and initializing training data


training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")

#initialize training data

# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")

# building gui

from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('/Users/joaquindelaguardia/Desktop/intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

#extract info from files

def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

#Creating GUI with tkinter

from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)


base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/joaquindelaguardia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/joaquindelaguardia/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 362 documents
# 38 classes ['admission', 'canteen', 'civilhod', 'college intake', 'committee', 'course', 'creator', 'document', 'event', 'facilities', 'fees', 'floors', 'goodbye', 'greeting', 'hod', 'hostel', 'hours', 'infrastructure', 'ithod', 'library', 'location', 'mechhod', 'menu', 'metro', 'name', 'number', 'placement', 'principal', 'ragging', 'random', 'salutaion', 'sem', 'swear', 'syllabus', 'task', 'transport', 'uniform', 'vacation']
# 251 unique lemmatized words ["'s", '835', 'a', 'about', 'active', 'address', 'admision', 'admission', 'allotment', 'am', 'an', 'and', 'antiragging', 'any', 'anyone', 'are', 'as', 'asshole', 'at', 'attend', 'available', 'average', 'be', 'between', 'big', 'bitch', 'book', 'branch', 'bring', 'bu', 'building', 'bus', 'by', 'bye', 'cafetaria', 'call', 'called', 'campus', 'can', 'canteen', 'capacity', 'case', 'casuals', 'chatting', 'civil', 'closest', 'code', 'college', 'come', 'committe', 'committee', 'company', 'conducted', 'contact', 'course', 'create', 'created', 'creator', 'cya', 'date', 'day', 'designed', 'detail', 'developer', 'different', 'distance', 'do', 'document', 'doe', 'done', 'dress', 'dresscode', 'dtc', 'dumb', 'during', 'each', 'end', 'engineering', 'event', 'exam', 'facility', 'far', 'fee', 'first', 'floor', 'food', 'for', 'from', 'fuck', 'fucker', 'function', 'get', 'give', 'go', 'good', 'goodbye', 'got', 'gtg', 'guy', 'have', 'held', 'hell', 'hello', 'help', 'here', 'heyy', 'hi', 'history', 'hod', 'holiday', 'hostel', 'hour', 'how', 'i', 'idiot', 'in', 'incident', 'info', 'information', 'infrastructure', 'intake', 'is', 'it', 'job', 'junior', 'k', 'later', 'leaving', 'lecture', 'library', 'list', 'located', 'location', 'long', 'love', 'made', 'many', 'marry', 'max', 'maximum', 'me', 'mechanical', 'menu', 'metro', 'mode', 'mor', 'more', 'much', 'my', 'name', 'near', 'nearby', 'nearest', 'need', 'needed', 'next', 'nice', 'no', 'number', 'of', 'offer', 'offered', 'office', 'ok', 'okay', 'okie', 'okk', 'on', 'open', 'operation', 'organised', 'package', 'per', 'phone', 'placement', 'practice', 'principal', 'process', 'provide', 'provided', 'ragging', 'rawta', 'reach', 'recruitment', 'required', 'route', 'saturday', 'schedule', 'seat', 'see', 'sem', 'semester', 'servive', 'should', 'shut', 'size', 'something', 'start', 'station', 'student', 'stundent', 'stupid', 'syllabus', 'take', 'taken', 'taking', 'talk', 'tall', 'technology', 'telephone', 'tell', 'thank', 'thanks', 'the', 'there', 'thing', 'this', 'time', 'timetable', 'timing', 'to', 'transportation', 'travelling', 'tyyl', 'u', 'uniform', 'up', 'use', 'vacation', 'visit', 'we', 'wear', 'well', 'what', 'whats', 'whatsup', 'whatv', 'when', 'where', 'wheres', 'which', 'who', 'whom', 'why', 'will', 'work', 'working', 'ya', 'year', 'you', 'your']
# Training data created
# <ipython-input-1-763014fb7580>:81: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)
# /Users/joaquindelaguardia/opt/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/200
# 73/73 [==============================] - 1s 2ms/step - loss: 3.6191 - accuracy: 0.0718
# Epoch 2/200
# 73/73 [==============================] - 0s 2ms/step - loss: 3.4749 - accuracy: 0.1271
# Epoch 3/200
# 73/73 [==============================] - 0s 2ms/step - loss: 3.3127 - accuracy: 0.1547
# Epoch 4/200
# 73/73 [==============================] - 0s 2ms/step - loss: 3.0728 - accuracy: 0.2099
# Epoch 5/200
# 73/73 [==============================] - 0s 2ms/step - loss: 2.8717 - accuracy: 0.2376
# Epoch 6/200
# 73/73 [==============================] - 0s 2ms/step - loss: 2.6402 - accuracy: 0.3066
# Epoch 7/200
# 73/73 [==============================] - 0s 2ms/step - loss: 2.3814 - accuracy: 0.3729
# Epoch 8/200
# 73/73 [==============================] - 0s 2ms/step - loss: 2.1725 - accuracy: 0.4420
# Epoch 9/200
# 73/73 [==============================] - 0s 2ms/step - loss: 1.9483 - accuracy: 0.5083
# Epoch 10/200
# 73/73 [==============================] - 0s 2ms/step - loss: 1.7377 - accuracy: 0.5331
# Epoch 11/200
# 73/73 [==============================] - 0s 2ms/step - loss: 1.5901 - accuracy: 0.5884
# Epoch 12/200
# 73/73 [==============================] - 0s 2ms/step - loss: 1.4437 - accuracy: 0.5994
# Epoch 13/200
# 73/73 [==============================] - 0s 2ms/step - loss: 1.2541 - accuracy: 0.6602
# Epoch 14/200
# 73/73 [==============================] - 0s 2ms/step - loss: 1.2239 - accuracy: 0.6630
# Epoch 15/200
# 73/73 [==============================] - 0s 2ms/step - loss: 1.0593 - accuracy: 0.6851
# Epoch 16/200
# 73/73 [==============================] - 0s 2ms/step - loss: 1.0494 - accuracy: 0.6961
# Epoch 17/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.9620 - accuracy: 0.7155
# Epoch 18/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8576 - accuracy: 0.7431
# Epoch 19/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8728 - accuracy: 0.7403
# Epoch 20/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7263 - accuracy: 0.7901
# Epoch 21/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7018 - accuracy: 0.7956
# Epoch 22/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6900 - accuracy: 0.7680
# Epoch 23/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6594 - accuracy: 0.7818
# Epoch 24/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7710 - accuracy: 0.7735
# Epoch 25/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.5222 - accuracy: 0.8564
# Epoch 26/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4553 - accuracy: 0.8702
# Epoch 27/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.5585 - accuracy: 0.8343
# Epoch 28/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.5463 - accuracy: 0.8287
# Epoch 29/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4674 - accuracy: 0.8674
# Epoch 30/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4699 - accuracy: 0.8646
# Epoch 31/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3782 - accuracy: 0.8895
# Epoch 32/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4668 - accuracy: 0.8591
# Epoch 33/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.4429 - accuracy: 0.8674
# Epoch 34/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4394 - accuracy: 0.8619
# Epoch 35/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.5045 - accuracy: 0.8481
# Epoch 36/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.3705 - accuracy: 0.8812
# Epoch 37/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.3902 - accuracy: 0.8785
# Epoch 38/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.3748 - accuracy: 0.8895
# Epoch 39/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.3684 - accuracy: 0.8923
# Epoch 40/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2819 - accuracy: 0.9227
# Epoch 41/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3034 - accuracy: 0.9006
# Epoch 42/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3480 - accuracy: 0.9061
# Epoch 43/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2589 - accuracy: 0.9309
# Epoch 44/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8867
# Epoch 45/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2666 - accuracy: 0.9282
# Epoch 46/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2765 - accuracy: 0.9088
# Epoch 47/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2637 - accuracy: 0.9337
# Epoch 48/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8895
# Epoch 49/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.3603 - accuracy: 0.8729
# Epoch 50/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.3009 - accuracy: 0.9282
# Epoch 51/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2760 - accuracy: 0.9282
# Epoch 52/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2575 - accuracy: 0.9144
# Epoch 53/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2989 - accuracy: 0.9144
# Epoch 54/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2223 - accuracy: 0.9503
# Epoch 55/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2431 - accuracy: 0.9282
# Epoch 56/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1831 - accuracy: 0.9503
# Epoch 57/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1871 - accuracy: 0.9309
# Epoch 58/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2002 - accuracy: 0.9392
# Epoch 59/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2280 - accuracy: 0.9254
# Epoch 60/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2330 - accuracy: 0.9116
# Epoch 61/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2552 - accuracy: 0.9227
# Epoch 62/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2193 - accuracy: 0.9199
# Epoch 63/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1959 - accuracy: 0.9448
# Epoch 64/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2410 - accuracy: 0.9309
# Epoch 65/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1857 - accuracy: 0.9420
# Epoch 66/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2209 - accuracy: 0.9282
# Epoch 67/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1825 - accuracy: 0.9420
# Epoch 68/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2317 - accuracy: 0.9309
# Epoch 69/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2200 - accuracy: 0.9282
# Epoch 70/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2388 - accuracy: 0.9254
# Epoch 71/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1872 - accuracy: 0.9475
# Epoch 72/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2209 - accuracy: 0.9144
# Epoch 73/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2678 - accuracy: 0.9282
# Epoch 74/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2145 - accuracy: 0.9282
# Epoch 75/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1590 - accuracy: 0.9530
# Epoch 76/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2258 - accuracy: 0.9254
# Epoch 77/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1740 - accuracy: 0.9613
# Epoch 78/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1652 - accuracy: 0.9586
# Epoch 79/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1851 - accuracy: 0.9475
# Epoch 80/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1790 - accuracy: 0.9420
# Epoch 81/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2379 - accuracy: 0.9282
# Epoch 82/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2079 - accuracy: 0.9309
# Epoch 83/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.2138 - accuracy: 0.9365
# Epoch 84/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1674 - accuracy: 0.9586
# Epoch 85/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1962 - accuracy: 0.9392
# Epoch 86/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2625 - accuracy: 0.9227
# Epoch 87/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1666 - accuracy: 0.9503
# Epoch 88/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1601 - accuracy: 0.9392
# Epoch 89/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2379 - accuracy: 0.9254
# Epoch 90/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1555 - accuracy: 0.9641
# Epoch 91/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2217 - accuracy: 0.9199
# Epoch 92/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.1795 - accuracy: 0.9448
# Epoch 93/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.9420
# Epoch 94/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1441 - accuracy: 0.9448
# Epoch 95/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2063 - accuracy: 0.9282
# Epoch 96/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9530
# Epoch 97/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2296 - accuracy: 0.9337
# Epoch 98/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1379 - accuracy: 0.9641
# Epoch 99/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1291 - accuracy: 0.9558
# Epoch 100/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1333 - accuracy: 0.9613
# Epoch 101/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1375 - accuracy: 0.9475
# Epoch 102/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1450 - accuracy: 0.9503
# Epoch 103/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2134 - accuracy: 0.9365
# Epoch 104/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2091 - accuracy: 0.9392
# Epoch 105/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.1540 - accuracy: 0.9613
# Epoch 106/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.1291 - accuracy: 0.9530
# Epoch 107/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1542 - accuracy: 0.9448
# Epoch 108/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1614 - accuracy: 0.9448
# Epoch 109/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1906 - accuracy: 0.9365
# Epoch 110/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1294 - accuracy: 0.9641
# Epoch 111/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1794 - accuracy: 0.9392
# Epoch 112/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1232 - accuracy: 0.9530
# Epoch 113/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.1485 - accuracy: 0.9586
# Epoch 114/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1681 - accuracy: 0.9558
# Epoch 115/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1217 - accuracy: 0.9586
# Epoch 116/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1034 - accuracy: 0.9724
# Epoch 117/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1350 - accuracy: 0.9586
# Epoch 118/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1401 - accuracy: 0.9669
# Epoch 119/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1262 - accuracy: 0.9586
# Epoch 120/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1701 - accuracy: 0.9696
# Epoch 121/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1427 - accuracy: 0.9503
# Epoch 122/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1336 - accuracy: 0.9530
# Epoch 123/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1600 - accuracy: 0.9586
# Epoch 124/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1177 - accuracy: 0.9613
# Epoch 125/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.9696
# Epoch 126/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2168 - accuracy: 0.9475
# Epoch 127/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1159 - accuracy: 0.9586
# Epoch 128/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1459 - accuracy: 0.9530
# Epoch 129/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.0672 - accuracy: 0.9779
# Epoch 130/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2026 - accuracy: 0.9309
# Epoch 131/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1469 - accuracy: 0.9613
# Epoch 132/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1400 - accuracy: 0.9558
# Epoch 133/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1427 - accuracy: 0.9613
# Epoch 134/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1677 - accuracy: 0.9475
# Epoch 135/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1646 - accuracy: 0.9530
# Epoch 136/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1197 - accuracy: 0.9641
# Epoch 137/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1499 - accuracy: 0.9448
# Epoch 138/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1471 - accuracy: 0.9503
# Epoch 139/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1464 - accuracy: 0.9558
# Epoch 140/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1176 - accuracy: 0.9530
# Epoch 141/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1468 - accuracy: 0.9475
# Epoch 142/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1619 - accuracy: 0.9558
# Epoch 143/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1366 - accuracy: 0.9558
# Epoch 144/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1252 - accuracy: 0.9613
# Epoch 145/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1050 - accuracy: 0.9613
# Epoch 146/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1676 - accuracy: 0.9448
# Epoch 147/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.0854 - accuracy: 0.9696
# Epoch 148/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1081 - accuracy: 0.9696
# Epoch 149/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1358 - accuracy: 0.9558
# Epoch 150/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1150 - accuracy: 0.9613
# Epoch 151/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.0873 - accuracy: 0.9696
# Epoch 152/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1236 - accuracy: 0.9669
# Epoch 153/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1021 - accuracy: 0.9669
# Epoch 154/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1321 - accuracy: 0.9669
# Epoch 155/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1153 - accuracy: 0.9641
# Epoch 156/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1457 - accuracy: 0.9503
# Epoch 157/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1096 - accuracy: 0.9475
# Epoch 158/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1158 - accuracy: 0.9641
# Epoch 159/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1649 - accuracy: 0.9558
# Epoch 160/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1985 - accuracy: 0.9530
# Epoch 161/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1303 - accuracy: 0.9586
# Epoch 162/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.0823 - accuracy: 0.9751
# Epoch 163/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1884 - accuracy: 0.9420
# Epoch 164/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.0820 - accuracy: 0.9696
# Epoch 165/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1399 - accuracy: 0.9503
# Epoch 166/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.9669
# Epoch 167/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1123 - accuracy: 0.9751
# Epoch 168/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1130 - accuracy: 0.9669
# Epoch 169/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1529 - accuracy: 0.9475
# Epoch 170/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.0770 - accuracy: 0.9696
# Epoch 171/200
# 73/73 [==============================] - 0s 4ms/step - loss: 0.1164 - accuracy: 0.9613
# Epoch 172/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.1095 - accuracy: 0.9586
# Epoch 173/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.1318 - accuracy: 0.9613
# Epoch 174/200
# 73/73 [==============================] - 0s 4ms/step - loss: 0.1246 - accuracy: 0.9530
# Epoch 175/200
# 73/73 [==============================] - 0s 5ms/step - loss: 0.1249 - accuracy: 0.9613: 0s - loss: 0.1331 - accuracy
# Epoch 176/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.1571 - accuracy: 0.9530
# Epoch 177/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1564 - accuracy: 0.9613
# Epoch 178/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1233 - accuracy: 0.9503
# Epoch 179/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1455 - accuracy: 0.9586
# Epoch 180/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1651 - accuracy: 0.9558
# Epoch 181/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.9751
# Epoch 182/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1338 - accuracy: 0.9586
# Epoch 183/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 0.9558
# Epoch 184/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1119 - accuracy: 0.9641
# Epoch 185/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.1458 - accuracy: 0.9530
# Epoch 186/200
# 73/73 [==============================] - 0s 4ms/step - loss: 0.0871 - accuracy: 0.9724
# Epoch 187/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.0651 - accuracy: 0.9751
# Epoch 188/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9669
# Epoch 189/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1174 - accuracy: 0.9696
# Epoch 190/200
# 73/73 [==============================] - 0s 6ms/step - loss: 0.0973 - accuracy: 0.9751
# Epoch 191/200
# 73/73 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.98 - 0s 3ms/step - loss: 0.0829 - accuracy: 0.9779
# Epoch 192/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.1275 - accuracy: 0.9696
# Epoch 193/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1323 - accuracy: 0.9613
# Epoch 194/200
# 73/73 [==============================] - 0s 3ms/step - loss: 0.1756 - accuracy: 0.9309
# Epoch 195/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1432 - accuracy: 0.9669
# Epoch 196/200
# 73/73 [==============================] - 0s 2ms/step - loss: 0.1284 - accuracy: 0.9558
# Epoch 197/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1131 - accuracy: 0.9586
# Epoch 198/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1139 - accuracy: 0.9696
# Epoch 199/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1229 - accuracy: 0.9696
# Epoch 200/200
# 73/73 [==============================] - 0s 1ms/step - loss: 0.1528 - accuracy: 0.9503
# model created
